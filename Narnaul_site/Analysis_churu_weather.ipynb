# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
# Loading the dataframe
data = pd.read_csv('data/Weather Data/Data_churu.csv', index_col = 0)
data.head()
# Out:
#                      Battery Level (V)  Relative Humidity (%)  \
# 2017-11-01 00:00:00            11.9501                35.7601
# 2017-11-01 00:01:00            11.9502                35.9886
# 2017-11-01 00:02:00            11.9500                35.9945
# 2017-11-01 00:03:00            11.9498                35.9791
# 2017-11-01 00:04:00            11.9541                35.7187
#
#                      Air Temperature (°C)  Wind Speed (m/s)  \
# 2017-11-01 00:00:00               20.3621          0.352892
# 2017-11-01 00:01:00               20.3087          0.337947
# 2017-11-01 00:02:00               20.2493          0.378700
# 2017-11-01 00:03:00               20.2707          0.397608
# 2017-11-01 00:04:00               20.3030          0.467771
#
#                      Wind Direction (°)  Dew Point (°C)  \
# 2017-11-01 00:00:00             154.235         4.62828
# 2017-11-01 00:01:00             168.267         4.67194
# 2017-11-01 00:02:00             173.513         4.62134
# 2017-11-01 00:03:00             176.708         4.63441
# 2017-11-01 00:04:00             173.482         4.55877
#
#                      Global Radiation 1 (W/m2)  Diffuse Radiation (W/m2)  \
# 2017-11-01 00:00:00                        0.0                       0.0
# 2017-11-01 00:01:00                        0.0                       0.0
# 2017-11-01 00:02:00                        0.0                       0.0
# 2017-11-01 00:03:00                        0.0                       0.0
# 2017-11-01 00:04:00                        0.0                       0.0
#
#                      Atmospheric Pressure QNH (mb)  \
# 2017-11-01 00:00:00                        1012.81
# 2017-11-01 00:01:00                        1012.80
# 2017-11-01 00:02:00                        1012.80
# 2017-11-01 00:03:00                        1012.80
# 2017-11-01 00:04:00                        1012.80
#
#                      Atmospheric Pressure QFE (mb)  Direct Radiation 1 (W/m2)  \
# 2017-11-01 00:00:00                        973.898                        0.0
# 2017-11-01 00:01:00                        973.896                        0.0
# 2017-11-01 00:02:00                        973.897                        0.0
# 2017-11-01 00:03:00                        973.896                        0.0
# 2017-11-01 00:04:00                        973.896                        0.0
#
#                      Solar Azimuth (°)  Global Energy 1 (kWh/m2)  \
# 2017-11-01 00:00:00            101.532                       0.0
# 2017-11-01 00:01:00            101.532                       0.0
# 2017-11-01 00:02:00            101.532                       0.0
# 2017-11-01 00:03:00            101.532                       0.0
# 2017-11-01 00:04:00            101.532                       0.0
#
#                      Diffuse Energy 1 (kWh/m2)  Direct Energy 1 (kWh/m2)  \
# 2017-11-01 00:00:00                        0.0                       0.0
# 2017-11-01 00:01:00                        0.0                       0.0
# 2017-11-01 00:02:00                        0.0                       0.0
# 2017-11-01 00:03:00                        0.0                       0.0
# 2017-11-01 00:04:00                        0.0                       0.0
#
#                      Global Energy 1 (MJ/m2)  Diffuse Energy 1 (MJ/m2)  \
# 2017-11-01 00:00:00                      0.0                       0.0
# 2017-11-01 00:01:00                      0.0                       0.0
# 2017-11-01 00:02:00                      0.0                       0.0
# 2017-11-01 00:03:00                      0.0                       0.0
# 2017-11-01 00:04:00                      0.0                       0.0
#
#                      Direct Energy 1 (MJ/m2)
# 2017-11-01 00:00:00                      0.0
# 2017-11-01 00:01:00                      0.0
# 2017-11-01 00:02:00                      0.0
# 2017-11-01 00:03:00                      0.0
# 2017-11-01 00:04:00                      0.0

# %%
print(data.columns)
# Out:
# Index(['Battery Level (V)', 'Relative Humidity (%)', 'Air Temperature (°C)',
#        'Wind Speed (m/s)', 'Wind Direction (°)', 'Dew Point (°C)',
#        'Global Radiation 1 (W/m2)', 'Diffuse Radiation (W/m2)',
#        'Atmospheric Pressure QNH (mb)', 'Atmospheric Pressure QFE (mb)',
#        'Direct Radiation 1 (W/m2)', 'Solar Azimuth (°)',
#        'Global Energy 1 (kWh/m2)', 'Diffuse Energy 1 (kWh/m2)',
#        'Direct Energy 1 (kWh/m2)', 'Global Energy 1 (MJ/m2)',
#        'Diffuse Energy 1 (MJ/m2)', 'Direct Energy 1 (MJ/m2)'],
#       dtype='object')

# %% [markdown]
# ### Data is huge
# Therefore selecting every 5th minute

# %%
data_red15= data.loc[::15, :]
data.index = pd.to_datetime(data.index)

# %% [markdown]
# ### Analyzing the graphs of various features

# %%
for col in ['Battery Level (V)','Relative Humidity (%)','Air Temperature (°C)','Global Radiation 1 (W/m2)','Solar Azimuth (°)']:
    plt.figure(figsize=[30,2])
    temp = data[data.index.hour == 13][col]
    # Comparing relative humidity only at 1:00 pm
    plt.plot(temp)
    plt.title(col)
plt.show()
